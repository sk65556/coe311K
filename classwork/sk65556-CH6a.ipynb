# %% [markdown]
# ## Comparing Convergence

# %% [markdown]
# ### python time module
# #### how many iterations did it take and how long

# %%
import numpy as np
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    print(x)
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
        print(x)
    return x, max_iterations

# %%
A=([[10,1,2,3,1],
    [1,12,1,2,3],
    [2,1,14,1,2],
    [3,2,1,15,1],
    [1,3,2,1,16]])
B=([[2,4,5,3,6],])
