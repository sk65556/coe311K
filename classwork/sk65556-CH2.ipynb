# %% [markdown]
# ## Challenge Two

# %%
import numpy as np

rb=[]
i=2025
while i>0:
    if i %2==0:
        i=int(i/2)
        rb.append(0)
        #print(i)
    else:
        i=int(i/2)
        rb.append(1)
        #print(i)

remainder=[]
j=1
x=len(rb)
while x>0:
    remainder.append(rb[-j])
    j=j+1
    x=x-1
print(remainder)
# Out:
# [1, 1, 1, 1, 1, 1, 0, 1, 0, 0, 1]
