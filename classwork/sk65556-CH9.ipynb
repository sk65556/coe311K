# %% [markdown]
# ## Least Squares

# %%
import numpy as np
# Data points
X = np.array([1, 2, 3, 4, 5])
Y = np.array([1.2, 2.8, 3.6, 4.5, 5.1])
# Stack the design matrix with a column of ones (for the intercept)
A = np.vstack([X, np.ones(len(X))]).T

print('X:')
print(X)
print('Y:')
print(Y)
print('A')
print(A)
# Out:
# X:
# [1 2 3 4 5]
# Y:
# [1.2 2.8 3.6 4.5 5.1]
# A
# [[1. 1.]
#  [2. 1.]
#  [3. 1.]
#  [4. 1.]
#  [5. 1.]]

# %%
# Solve using least squares
m, c = np.linalg.lstsq(A, Y, rcond=None)[0]
print(f"Slope: {m}, Intercept: {c}")
# Out:
# Slope: 0.9500000000000001, Intercept: 0.5900000000000001

# %%
import matplotlib.pyplot as plt
from numpy.random import default_rng
rng=default_rng(2)

plt.figure()
plt.scatter(X,Y,color="#512da8",label='X,Y')
x=max,min
y=0.95*X+0.59
plt.plot(y,label='y=0.95x+0.59',color='#01153E')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
from numpy.random import default_rng
rng=default_rng(2)
x=rng.random(0,10,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-3f1a6d2d88d3> in <module>
#       1 from numpy.random import default_rng
#       2 rng=default_rng(2)
# ----> 3 x=rng.random(0,10,5)
#
# generator.pyx in numpy.random.generator.Generator.random()
#
# TypeError: data type not understood

# %%
x=linspace(0,2,.01)
ran=linspace(-1,1)
